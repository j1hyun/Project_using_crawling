# %%
import pandas

def somecalulation(x): #'게시 날짜' 열이 중복된 행 개수 찾기
    return (df['게시 날짜'] == x).sum()

df=pd.read_csv('instagram_daejeo_2018.csv', index_col=False)

dt_index = pandas.date_range(start='20180101', end='20181231') 
dt_list = dt_index.strftime("%Y-%m-%d").tolist()

count_list=[]

for i in dt_list:
    print(i)
    print(somecalulation(i))
    count_list.append((i, somecalulation(i)))

file=pd.DataFrame(count_list, columns=['게시날짜', '게시글수'])
file.to_csv('instagram_daejeo_2018_count.csv', mode='wt', encoding='utf-8-sig', header=True, index=False)
# Out:
# 2018-01-01
# 5
# 2018-01-02
# 9
# 2018-01-03
# 5
# 2018-01-04
# 4
# 2018-01-05
# 4
# 2018-01-06
# 1
# 2018-01-07
# 2
# 2018-01-08
# 5
# 2018-01-09
# 4
# 2018-01-10
# 5
# 2018-01-11
# 9
# 2018-01-12
# 8
# 2018-01-13
# 5
# 2018-01-14
# 10
# 2018-01-15
# 10
# 2018-01-16
# 5
# 2018-01-17
# 3
# 2018-01-18
# 4
# 2018-01-19
# 5
# 2018-01-20
# 8
# 2018-01-21
# 6
# 2018-01-22
# 3
# 2018-01-23
# 3
# 2018-01-24
# 0
# 2018-01-25
# 2
# 2018-01-26
# 4
# 2018-01-27
# 1
# 2018-01-28
# 4
# 2018-01-29
# 3
# 2018-01-30
# 2
# 2018-01-31
# 0
# 2018-02-01
# 0
# 2018-02-02
# 0
# 2018-02-03
# 2
# 2018-02-04
# 3
# 2018-02-05
# 3
# 2018-02-06
# 0
# 2018-02-07
# 0
# 2018-02-08
# 0
# 2018-02-09
# 0
# 2018-02-10
# 0
# 2018-02-11
# 0
# 2018-02-12
# 0
# 2018-02-13
# 0
# 2018-02-14
# 0
# 2018-02-15
# 0
# 2018-02-16
# 0
# 2018-02-17
# 2
# 2018-02-18
# 9
# 2018-02-19
# 5
# 2018-02-20
# 5
# 2018-02-21
# 5
# 2018-02-22
# 4
# 2018-02-23
# 6
# 2018-02-24
# 6
# 2018-02-25
# 10
# 2018-02-26
# 7
# 2018-02-27
# 4
# ...

# %%
import pandas

def somecalulation(x):
    return (df['게시 날짜'] == x).sum()

df=pd.read_csv('instagram_daejeo_2019.csv', index_col=False)

dt_index = pandas.date_range(start='20190101', end='20191231')
dt_list = dt_index.strftime("%Y-%m-%d").tolist()

count_list=[]

for i in dt_list:
    print(i)
    print(somecalulation(i))
    count_list.append((i, somecalulation(i)))

file=pd.DataFrame(count_list, columns=['게시날짜', '게시글수'])
file.to_csv('instagram_daejeo_2019_count.csv', mode='wt', encoding='utf-8-sig', header=True, index=False)
# Out:
# 2019-01-01
# 1
# 2019-01-02
# 1
# 2019-01-03
# 4
# 2019-01-04
# 13
# 2019-01-05
# 9
# 2019-01-06
# 14
# 2019-01-07
# 8
# 2019-01-08
# 6
# 2019-01-09
# 6
# 2019-01-10
# 4
# 2019-01-11
# 5
# 2019-01-12
# 4
# 2019-01-13
# 10
# 2019-01-14
# 4
# 2019-01-15
# 5
# 2019-01-16
# 2
# 2019-01-17
# 5
# 2019-01-18
# 4
# 2019-01-19
# 4
# 2019-01-20
# 9
# 2019-01-21
# 4
# 2019-01-22
# 4
# 2019-01-23
# 5
# 2019-01-24
# 4
# 2019-01-25
# 5
# 2019-01-26
# 0
# 2019-01-27
# 0
# 2019-01-28
# 0
# 2019-01-29
# 0
# 2019-01-30
# 0
# 2019-01-31
# 0
# 2019-02-01
# 0
# 2019-02-02
# 0
# 2019-02-03
# 0
# 2019-02-04
# 0
# 2019-02-05
# 1
# 2019-02-06
# 2
# 2019-02-07
# 6
# 2019-02-08
# 7
# 2019-02-09
# 6
# 2019-02-10
# 3
# 2019-02-11
# 4
# 2019-02-12
# 8
# 2019-02-13
# 4
# 2019-02-14
# 7
# 2019-02-15
# 9
# 2019-02-16
# 7
# 2019-02-17
# 7
# 2019-02-18
# 7
# 2019-02-19
# 1
# 2019-02-20
# 8
# 2019-02-21
# 5
# 2019-02-22
# 6
# 2019-02-23
# 3
# 2019-02-24
# 15
# 2019-02-25
# 8
# 2019-02-26
# 5
# 2019-02-27
# 6
# ...

# %%
import pandas

def somecalulation(x):
    return (df['게시 날짜'] == x).sum()

df=pd.read_csv('instagram_samrak_2018.csv', index_col=False)

dt_index = pandas.date_range(start='20180101', end='20181231')
dt_list = dt_index.strftime("%Y-%m-%d").tolist()

count_list=[]

for i in dt_list:
    print(i)
    print(somecalulation(i))
    count_list.append((i, somecalulation(i)))

file=pd.DataFrame(count_list, columns=['게시날짜', '게시글수'])
file.to_csv('instagram_samrak_2018_count.csv', mode='wt', encoding='utf-8-sig', header=True, index=False)
# Out:
# 2018-01-01
# 0
# 2018-01-02
# 2
# 2018-01-03
# 0
# 2018-01-04
# 0
# 2018-01-05
# 0
# 2018-01-06
# 2
# 2018-01-07
# 0
# 2018-01-08
# 0
# 2018-01-09
# 0
# 2018-01-10
# 0
# 2018-01-11
# 0
# 2018-01-12
# 0
# 2018-01-13
# 0
# 2018-01-14
# 3
# 2018-01-15
# 2
# 2018-01-16
# 0
# 2018-01-17
# 1
# 2018-01-18
# 1
# 2018-01-19
# 0
# 2018-01-20
# 2
# 2018-01-21
# 0
# 2018-01-22
# 1
# 2018-01-23
# 1
# 2018-01-24
# 2
# 2018-01-25
# 1
# 2018-01-26
# 0
# 2018-01-27
# 4
# 2018-01-28
# 4
# 2018-01-29
# 0
# 2018-01-30
# 0
# 2018-01-31
# 4
# 2018-02-01
# 0
# 2018-02-02
# 0
# 2018-02-03
# 0
# 2018-02-04
# 0
# 2018-02-05
# 0
# 2018-02-06
# 0
# 2018-02-07
# 2
# 2018-02-08
# 1
# 2018-02-09
# 0
# 2018-02-10
# 1
# 2018-02-11
# 3
# 2018-02-12
# 0
# 2018-02-13
# 0
# 2018-02-14
# 1
# 2018-02-15
# 2
# 2018-02-16
# 0
# 2018-02-17
# 1
# 2018-02-18
# 3
# 2018-02-19
# 4
# 2018-02-20
# 0
# 2018-02-21
# 1
# 2018-02-22
# 0
# 2018-02-23
# 0
# 2018-02-24
# 0
# 2018-02-25
# 0
# 2018-02-26
# 0
# 2018-02-27
# 0
# 2018-02-28
# ...

# %%
import pandas

def somecalulation(x):
    return (df['게시 날짜'] == x).sum()

df=pd.read_csv('instagram_samrak_2019.csv', index_col=False)

dt_index = pandas.date_range(start='20190101', end='20191231')
dt_list = dt_index.strftime("%Y-%m-%d").tolist()

count_list=[]

for i in dt_list:
    print(i)
    print(somecalulation(i))
    count_list.append((i, somecalulation(i)))

file=pd.DataFrame(count_list, columns=['게시날짜', '게시글수'])
file.to_csv('instagram_samrak_2019_count.csv', mode='wt', encoding='utf-8-sig', header=True, index=False)
# Out:
# 2019-01-01
# 3
# 2019-01-02
# 1
# 2019-01-03
# 3
# 2019-01-04
# 1
# 2019-01-05
# 3
# 2019-01-06
# 4
# 2019-01-07
# 7
# 2019-01-08
# 2
# 2019-01-09
# 4
# 2019-01-10
# 3
# 2019-01-11
# 4
# 2019-01-12
# 7
# 2019-01-13
# 7
# 2019-01-14
# 4
# 2019-01-15
# 3
# 2019-01-16
# 1
# 2019-01-17
# 2
# 2019-01-18
# 2
# 2019-01-19
# 4
# 2019-01-20
# 9
# 2019-01-21
# 2
# 2019-01-22
# 1
# 2019-01-23
# 2
# 2019-01-24
# 1
# 2019-01-25
# 2
# 2019-01-26
# 7
# 2019-01-27
# 7
# 2019-01-28
# 3
# 2019-01-29
# 1
# 2019-01-30
# 7
# 2019-01-31
# 6
# 2019-02-01
# 3
# 2019-02-02
# 3
# 2019-02-03
# 0
# 2019-02-04
# 0
# 2019-02-05
# 0
# 2019-02-06
# 4
# 2019-02-07
# 2
# 2019-02-08
# 2
# 2019-02-09
# 0
# 2019-02-10
# 0
# 2019-02-11
# 0
# 2019-02-12
# 0
# 2019-02-13
# 0
# 2019-02-14
# 0
# 2019-02-15
# 0
# 2019-02-16
# 0
# 2019-02-17
# 0
# 2019-02-18
# 0
# 2019-02-19
# 0
# 2019-02-20
# 2
# 2019-02-21
# 5
# 2019-02-22
# 4
# 2019-02-23
# 6
# 2019-02-24
# 8
# 2019-02-25
# 2
# 2019-02-26
# 2
# 2019-02-27
# 7
# 2019-02-28
# ...
